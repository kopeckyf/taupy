# %% [markdown]
# Wir laden zuerst `taupy` und speichern die Argumentations-Strategien extra im Namespace unter `strategies` ab, um sie gleich leichter zu erreichen.

# %%
from taupy import * 
import taupy.simulation.strategies as strategies

# %%
pos1ra = Position(debate=None, introduction_strategy=strategies.random)
pos2ra = Position(debate=None, introduction_strategy=strategies.random)

pos1fo = Position(debate=None, introduction_strategy=strategies.fortify)
pos2fo = Position(debate=None, introduction_strategy=strategies.fortify)

pos1at = Position(debate=None, introduction_strategy=strategies.attack)
pos2at = Position(debate=None, introduction_strategy=strategies.attack)

pos1co = Position(debate=None, introduction_strategy=strategies.convert)
pos2co = Position(debate=None, introduction_strategy=strategies.convert)

pos1un = Position(debate=None, introduction_strategy=strategies.undercut)
pos2un = Position(debate=None, introduction_strategy=strategies.undercut)

# %%
simra = Simulation(positions = [pos1ra, pos2ra])
simfo = Simulation(positions = [pos1fo, pos2fo])
simat = Simulation(positions = [pos1at, pos2at])
simco = Simulation(positions = [pos1co, pos2co])
simun = Simulation(positions = [pos1un, pos2un])

# %% [markdown]
# ## Simulationen ausführen
#
# Wir starten hier mit `Simulation.run()` die Simulationen unter den Voreinstellungen. Wir könnten auch `run(max_density = 0.8)` einstellen - dann würde die Simulation schon bei einer Dichte von 0.8 enden. Mit `max_steps` könnten wir eine maximale Anzahl der Schritte festlegen und mit `min_sccp` die minimale Anzahl von Positionen im SCCP, nach der die Simulation noch fortführt. Die Default-Werte sind `max_density=1, max_steps=1000, min_sccp=1`.

# %%
simra.run()
# Out:
# Simulation ended. 40 steps were taken. Density at end: 1.000000. Extension of SCCP: 1.

# %%
simfo.run()
# Out:
# Simulation ended. 41 steps were taken. Density at end: 1.000000. Extension of SCCP: 1.

# %%
simat.run()
# Out:
# Simulation ended. 76 steps were taken. Density at end: 0.767807. Extension of SCCP: 5.

# %%
simco.run()
# Out:
# Simulation ended. 50 steps were taken. Density at end: 1.000000. Extension of SCCP: 1.

# %%
simun.run()
# Out:
# Simulation ended. 24 steps were taken. Density at end: 0.600000. Extension of SCCP: 16.

# %% [markdown]
# ## Ergebnisse plotten
# Wir wollen jetzt noch den Verlauf des Durchmessers des SCCPs in diesen Debatten messen. Auf der x-Achse ist der Schritt angegeben, die y-Achse zeigt den Durchmesser. Der Durchmesser ist das einfachste Polarisierungsmaß.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Plot für Random

# %%
simra_spread = [spread([simra.positions[i][0], simra.positions[i][1]], normalised_hamming_distance) for i in range(len(simra.positions))]
plt.plot(simra_spread)

simra_divergence = [group_divergence(simra[i], measure=normalised_hamming_distance) for i in range(len(simra))]
plt.plot(simra_divergence)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-de31132a38bb> in <module>
#       5 plt.plot(simra_divergence)
#       6
# ----> 7 simra_lauka = [lauka([simra[i].list_of_positions()]) for i in range(len(simra))]
#       8 plt.plt(simra_lauka)
#
# <ipython-input-21-de31132a38bb> in <listcomp>(.0)
#       5 plt.plot(simra_divergence)
#       6
# ----> 7 simra_lauka = [lauka([simra[i].list_of_positions()]) for i in range(len(simra))]
#       8 plt.plt(simra_lauka)
#
# ~/Github/taupy/taupy/analysis/polarisation.py in lauka(positions)
#      37     """
#      38     _n = len(positions)
# ---> 39     _issues = {i.keys() for i in positions}
#      40     l = []
#      41
#
# ~/Github/taupy/taupy/analysis/polarisation.py in <setcomp>(.0)
#      37     """
#      38     _n = len(positions)
# ---> 39     _issues = {i.keys() for i in positions}
#      40     l = []
# ...

# %% [markdown]
# ### Plot für Fortify

# %%
simfo_spread = [spread([simfo.positions[i][0], simfo.positions[i][1]], normalised_hamming_distance) for i in range(len(simfo.positions))]
plt.plot(simfo_spread)

simfo_divergence = [group_divergence(simfo[i], measure=normalised_hamming_distance) for i in range(len(simfo))]
plt.plot(simfo_divergence)

# %% [markdown]
# ### Plot für Attack

# %%
simat_spread = [spread([simat.positions[i][0], simat.positions[i][1]], normalised_hamming_distance) for i in range(len(simat.positions))]
plt.plot(simat_spread)

simat_divergence = [group_divergence(simat[i], measure=normalised_hamming_distance) for i in range(len(simat))]
plt.plot(simat_divergence)

# %% [markdown]
# ### Plot für Convert

# %%
simco_spread = [spread([simco.positions[i][0], simco.positions[i][1]], normalised_hamming_distance) for i in range(len(simco.positions))]
plt.plot(simco_spread)

simco_divergence = [group_divergence(simco[i], measure=normalised_hamming_distance) for i in range(len(simco))]
plt.plot(simco_divergence)

# %% [markdown]
# ### Plot für Undercut

# %%
simun_spread = [spread([simun.positions[i][0], simun.positions[i][1]], normalised_hamming_distance) for i in range(len(simun.positions))]
plt.plot(simun_spread)

simun_divergence = [group_divergence(simun[i], measure=normalised_hamming_distance) for i in range(len(simun))]
plt.plot(simun_divergence)
